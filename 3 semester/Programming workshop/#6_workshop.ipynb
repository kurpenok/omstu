# %%
import pandas as pd
import seaborn as sns
from scipy import stats
import matplotlib.pyplot as plt

# %%
dairy_queen_menu_nutrition_df = pd.read_csv("data/dairy_queen_menu_nutrition.csv")

# %%
dairy_queen_menu_nutrition_df.head(5)
# Out:
#                                 Menu Item  Calories (kcal)  \
# 0        Caramel Mocha Chip Shake - Small            600.0
# 1       Caramel Mocha Chip Shake - Medium            830.0
# 2        Caramel Mocha Chip Shake - Large           1100.0
# 3   Cinnamon Roll Centers Blizzard - Mini            360.0
# 4  Cinnamon Roll Centers Blizzard - Small            620.0
#
#    Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 0                100.0           27.0               21.0            1.0
# 1                170.0           39.0               31.0            1.0
# 2                230.0           52.0               41.0            1.5
# 3                300.0           13.0                8.0            0.5
# 4                240.0           22.0               14.0            1.0
#
#    Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 0              45.0        240.0               79.0        1.0        65.0
# ...

# %%
dairy_queen_menu_nutrition_df.tail(5)
# Out:
#                                Menu Item  Calories (kcal)  \
# 224  Strawberry Banana Smoothie - XLarge            620.0
# 225         Tripleberry Smoothie - Large            460.0
# 226        Tripleberry Smoothie - Medium            370.0
# 227         Tripleberry Smoothie - Small            280.0
# 228        Tripleberry Smoothie - XLarge            660.0
#
#      Fat Calories (kcal)  Total Fat (g)  Saturated Fat (g)  Trans Fat (g)  \
# 224                  5.0            0.5                0.0            0.0
# 225                  0.0            0.0                0.0            0.0
# 226                  0.0            0.0                0.0            0.0
# 227                  0.0            0.0                0.0            0.0
# 228                  0.0            0.0                0.0            0.0
#
#      Cholesterol (mg)  Sodium (mg)  Carbohydrates (g)  Fiber (g)  Sugars (g)  \
# 224               0.0        240.0              144.0        5.0       131.0
# ...

# %%
dairy_queen_menu_nutrition_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Menu Item            229 non-null    object
#  1   Calories (kcal)      229 non-null    float64
#  2   Fat Calories (kcal)  229 non-null    float64
#  3   Total Fat (g)        229 non-null    float64
#  4   Saturated Fat (g)    229 non-null    float64
#  5   Trans Fat (g)        227 non-null    float64
#  6   Cholesterol (mg)     229 non-null    float64
#  7   Sodium (mg)          229 non-null    float64
#  8   Carbohydrates (g)    229 non-null    float64
#  9   Fiber (g)            229 non-null    float64
#  10  Sugars (g)           229 non-null    float64
#  11  Protein (g)          229 non-null    float64
#  12  Allergens            213 non-null    object
# dtypes: float64(11), object(2)
# memory usage: 23.4+ KB

# %%
dairy_queen_menu_nutrition_df = dairy_queen_menu_nutrition_df.drop_duplicates()

# %%
sns.histplot(data=dairy_queen_menu_nutrition_df, x="Calories (kcal)")
# Out:
# <AxesSubplot: xlabel='Calories (kcal)', ylabel='Count'>

# %%
sns.boxplot(data=dairy_queen_menu_nutrition_df, x="Calories (kcal)")
# Out:
# <AxesSubplot: xlabel='Calories (kcal)'>

# %%
plt.pie(dairy_queen_menu_nutrition_df["Fiber (g)"].unique())
# Out:
# ([<matplotlib.patches.Wedge at 0x7f118960d1e0>,
# ...
#  [Text(1.0973204551560924, 0.07673212297353954, ''),
#   Text(1.0573878634819256, 0.30320109854868443, ''),
#   Text(1.0048999988688236, 0.44741031757597916, ''),
#   Text(0.6772275987366253, 0.8668118478132523, ''),
#   Text(-0.03838950841467498, 1.0993299075544518, ''),
#   Text(-0.5500000706099085, 0.9526279033962295, ''),
#   Text(-1.0892948894314882, 0.1530903127517942, ''),
#   Text(-0.7360435834428704, -0.8174593832555709, ''),
#   Text(0.03838958560969535, -1.0993299048587353, ''),
#   Text(0.9328530002190023, -0.5829110395098092, '')])

# %%
sns.heatmap(dairy_queen_menu_nutrition_df.corr())
# Out:
# /tmp/ipykernel_6751/2321319257.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(dairy_queen_menu_nutrition_df.corr())
# <AxesSubplot: >

# %%
sns.countplot(data=dairy_queen_menu_nutrition_df, x="Calories (kcal)")
# Out:
# <AxesSubplot: xlabel='Calories (kcal)', ylabel='count'>

# %%
norm_check_selection = dairy_queen_menu_nutrition_df["Calories (kcal)"].iloc[:200]

# %%
stats.normaltest(norm_check_selection)
# Out:
# NormaltestResult(statistic=8.108456832755639, pvalue=0.017348861117649324)

# %%
ohe_df = pd.get_dummies(dairy_queen_menu_nutrition_df)
ohe_df.to_csv("")
